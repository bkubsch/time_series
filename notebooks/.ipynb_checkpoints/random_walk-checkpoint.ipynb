# %%
import pandas as pd
import numpy as np

from random import seed
from random import random
from matplotlib import pyplot

from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf

# %%
seed(1)
random_walk = list()
random_walk.append(-1 if random() < 0.5 else 1)
for i in range(1, 1000):
	movement = -1 if random() < 0.5 else 1
	value = random_walk[i-1] + movement
	random_walk.append(value)
pyplot.plot(random_walk)
pyplot.show()

# %%
type(random_walk)
# Out:
# list

# %%
plot_acf(np.asarray(random_walk), lags=50);

# %%
# take difference
diff = list()
for i in range(1, len(random_walk)):
	value = random_walk[i] - random_walk[i - 1]
	diff.append(value)
# line plot
autocorrelation_plot(diff)
pyplot.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
import datetime as dt
h = pd.date_range(dt.datetime(2019,6,15), dt.datetime(2019,7,31), freq="5min")
len(h)
# Out:
# 13249

# %%
df_random_walk = pd.DataFrame(index=h, data=random_walk, columns=["random_walk"])

# %%
df_random_walk.index
# Out:
# DatetimeIndex(['2019-06-15 00:00:00', '2019-06-15 00:05:00',
#                '2019-06-15 00:10:00', '2019-06-15 00:15:00',
#                '2019-06-15 00:20:00', '2019-06-15 00:25:00',
#                '2019-06-15 00:30:00', '2019-06-15 00:35:00',
#                '2019-06-15 00:40:00', '2019-06-15 00:45:00',
#                ...
#                '2019-07-30 23:15:00', '2019-07-30 23:20:00',
#                '2019-07-30 23:25:00', '2019-07-30 23:30:00',
#                '2019-07-30 23:35:00', '2019-07-30 23:40:00',
#                '2019-07-30 23:45:00', '2019-07-30 23:50:00',
#                '2019-07-30 23:55:00', '2019-07-31 00:00:00'],
#               dtype='datetime64[ns]', length=13249, freq='5T')
